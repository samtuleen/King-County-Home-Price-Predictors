# %% [markdown]
# # King County Home Price Predictors - An Analysis

# %% [markdown]
# By Sameeha Ramadhan

# %% [markdown]
# ![king_county.jpg](attachment:king_county.jpg)

# %% [markdown]
# ## Introduction

# %% [markdown]
# This analysis is based on the King County Housing Data Set which contains information about the size, location, condition, and other features of houses in King County. The aim of this project is to develop a regression model than can predict which home features positively affect house prices with the greatest accuracy possible.
#
# The model and examination is focused on single family homes and what are some of the many factors that contribute to real estate sales prices. The results can inform home owners interested in selling their homes about the most profitable improvements to consider for adding value to their home and thus increasing sale prices.

# %% [markdown]
# ## Analysis Goal
# This analysis will seek to answer a few important questions about the data, such as:
#
# Which features most strongly affect price?
#
# What should a new home buyer consider when purchasing a new home in terms of factors that determine the value of the property?
#
# What are some of the features that appear to have a relationship with King County housing sale prices?
#
# Validate a few claims made by real estate professions, such as the fact that higher square footage increases home sale price as well as having a deck.

# %% [markdown]
# ## The Data:
# The data used in this project is from the King County Department of Assessments website and can be found [here](https://info.kingcounty.gov/assessor/DataDownload/default.aspx). The following files that were used in this project are:
#
# **Real Property Sales**
#
# **Parcel**
#
# **Residential Building**
#
# **Lookup**
#
# My analysis was based the most recent data from 2018, 2019, and 2020 and the data was filtered accordingly.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import scipy.stats as stats
from scipy.stats import pearsonr
from itertools import combinations
import warnings


RPSale = pd.read_csv('../../data/raw/EXTR_RPSale.csv')
ResBldg = pd.read_csv('../../data/raw/EXTR_ResBldg.csv')
Parcel = pd.read_csv('../../data/raw/EXTR_Parcel.csv')

# %% [markdown]
# # Filtering the Data

# %% [markdown]
# ### Filtering to The Last 3 Years

# %%
Date = RPSale['DocumentDate'].str.split('/', expand=True)
RPSale['MonthSold'] = Date[0].astype('float64')
RPSale['YrSold'] = Date[2].astype('float64')

#Drop original date column
RPSale.drop(columns=['DocumentDate'], axis=1, inplace=True)

# %%
#filtering data from 2018, 2019 and 2020 only
years = [2018, 2019, 2020]  
    
properties = RPSale.loc[RPSale['YrSold'].isin(years)]  
    
properties
# Out:
#         ExciseTaxNbr   Major  Minor  SalePrice    RecordingNbr Volume Page  \
# 2            2999169  919715    200     192000  20190712001080
# 8            3000673  894444    200     185000  20190722001395
# 9            3027422  213043    120     560000  20191226000848
# 10           3002257  940652    630     435000  20190730001339
# 19           3018109  152504   9008    7600000  20191030001615
# ...              ...     ...    ...        ...             ...    ...  ...
# 351056       2997920  302300    320          0  20190705000539
# 351057       3028691  277110   4239     955000  20200103000685
# 351058       2934041  388580   3260    1375000  20180604000929
# 351062       2935450  219331    270     850000  20180612000762
# 351065       2971374  924600    650          0
#
#        PlatNbr PlatType         PlatLot  ... SaleInstrument AFForestLand  \
# 2                                        ...              3            N
# 8                                        ...              3            N
# 9                                        ...              3            N
# 10                                       ...              3            N
# 19                                       ...              3            N
# ...        ...      ...             ...  ...            ...          ...
# 351056                                   ...             15            N
# 351057                                   ...              3            N
# 351058                                   ...              3            N
# 351062                                   ...              3            N
# 351065                                   ...              3            N
#
#        AFCurrentUseLand  AFNonProfitUse  AFHistoricProperty  SaleReason  \
# 2                     N               N                   N           1
# 8                     N               N                   N           1
# 9                     N               N                   N           1
# 10                    N               N                   N           1
# 19                    N               N                   N           1
# ...                 ...             ...                 ...         ...
# 351056                N               N                   N           1
# 351057                N               N                   N           1
# 351058                N               N                   N           1
# 351062                N               N                   N           1
# 351065                N               N                   N           1
#
#        PropertyClass SaleWarning MonthSold  YrSold
# 2                  3                   7.0  2019.0
# 8                  3                   6.0  2019.0
# 9                  8                  12.0  2019.0
# 10                 8                   7.0  2019.0
# 19                 2                  10.0  2019.0
# ...              ...         ...       ...     ...
# 351056             8                   5.0  2019.0
# 351057             8                  12.0  2019.0
# 351058             8                   5.0  2018.0
# 351062             8                   6.0  2018.0
# 351065             8                   1.0  2019.0
#
# [143177 rows x 25 columns]

# %%
properties['YrSold'].value_counts()
# Out:
# 2019.0    61351
# 2018.0    61170
# 2020.0    20656
# Name: YrSold, dtype: int64

# %%
properties = properties.rename(columns=str.lower)

# %%
properties.head()
# Out:
#     excisetaxnbr   major  minor  saleprice    recordingnbr volume page  \
# 2        2999169  919715    200     192000  20190712001080
# 8        3000673  894444    200     185000  20190722001395
# 9        3027422  213043    120     560000  20191226000848
# 10       3002257  940652    630     435000  20190730001339
# 19       3018109  152504   9008    7600000  20191030001615
#
#    platnbr plattype         platlot  ... saleinstrument afforestland  \
# 2                                    ...              3            N
# 8                                    ...              3            N
# 9                                    ...              3            N
# 10                                   ...              3            N
# 19                                   ...              3            N
#
#    afcurrentuseland  afnonprofituse  afhistoricproperty  salereason  \
# 2                 N               N                   N           1
# 8                 N               N                   N           1
# 9                 N               N                   N           1
# 10                N               N                   N           1
# 19                N               N                   N           1
#
#    propertyclass salewarning monthsold  yrsold
# 2              3                   7.0  2019.0
# 8              3                   6.0  2019.0
# 9              8                  12.0  2019.0
# 10             8                   7.0  2019.0
# 19             2                  10.0  2019.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Padding the 'major' and 'minor' columns and merging them together:

# %%
properties['major'] = properties['major'].astype(str)
properties['minor'] = properties['minor'].astype(str)

def major_padded(row):
    if len(row) == 6:
        return row
    elif len(row) == 5:
        return '0'+row
    elif len(row) == 4:
        return '00'+row
    elif len(row) == 3:
        return '000'+row
    elif len(row) == 2:
        return '0000'+row
    elif len(row) == 1:
        return '00000'+row
    else:
        return '000000'

def minor_padded(row):
    if len(row) == 4:
        return row
    elif len(row) == 3: 
        return '0'+row
    elif len(row) == 2:
        return '00'+row
    elif len(row) == 1:
        return '000'+row
    else:
        return '0000'
    
properties['major'] = properties.major.apply(major_padded)
properties['minor'] = properties.minor.apply(minor_padded)
properties['major_minor'] = properties['major']+properties['minor']

# %%
#Dropping the old columns
to_drop = ['major','minor']
properties.drop(to_drop, axis=1, inplace=True)

# %%
#Moving the 'major_minor' column to the front
col_name = 'major_minor'
last_col = properties.pop(col_name)
properties.insert(1, col_name, last_col)

# %% [markdown]
# ### Narrowing the property type
# According to our LookUp file, the residental values are coded as follows:
#
# **11** - Household, single family units
#
# **12** - Multiple family residence (Residential, 2-4 units)
#
# **14** - Residential condominiums
#
# **18** - All other residential not elsewhere coded

# %%
properties = properties[properties['propertytype'].isin([11, 12, 14, 18])]
properties
# Out:
#         excisetaxnbr major_minor  saleprice    recordingnbr volume page  \
# 9            3027422  2130430120     560000  20191226000848
# 10           3002257  9406520630     435000  20190730001339
# 22           3015516  7797900030          0  20191016000009
# 24           2963345  7574800320          0  20181126001127
# 27           3033993  9264902060     370000  20200214001331
# ...              ...         ...        ...             ...    ...  ...
# 351043       3045715  4127000898     619000  20200505001286
# 351047       2949086  3597000405          0  20180824000032
# 351056       2997920  3023000320          0  20190705000539
# 351062       2935450  2193310270     850000  20180612000762
# 351065       2971374  9246000650          0
#
#        platnbr plattype         platlot platblock  ... saleinstrument  \
# 9                                                  ...              3
# 10                                                 ...              3
# 22                                                 ...              3
# 24                                                 ...             15
# 27                                                 ...              2
# ...        ...      ...             ...       ...  ...            ...
# 351043                                             ...              2
# 351047                                             ...             15
# 351056                                             ...             15
# 351062                                             ...              3
# 351065                                             ...              3
#
#        afforestland  afcurrentuseland  afnonprofituse  afhistoricproperty  \
# 9                 N                 N               N                   N
# 10                N                 N               N                   N
# 22                N                 N               N                   N
# 24                N                 N               N                   N
# 27                N                 N               N                   N
# ...             ...               ...             ...                 ...
# 351043            N                 N               N                   N
# 351047            N                 N               N                   N
# 351056            N                 N               N                   N
# 351062            N                 N               N                   N
# 351065            N                 N               N                   N
#
#        salereason propertyclass salewarning monthsold  yrsold
# 9               1             8                  12.0  2019.0
# 10              1             8                   7.0  2019.0
# 22              1             8                  10.0  2019.0
# 24              1             3                  11.0  2018.0
# 27              1             8                   2.0  2020.0
# ...           ...           ...         ...       ...     ...
# 351043          1             8                   4.0  2020.0
# 351047          1             8                   7.0  2018.0
# 351056          1             8                   5.0  2019.0
# 351062          1             8                   6.0  2018.0
# 351065          1             8                   1.0  2019.0
#
# [68394 rows x 24 columns]

# %% [markdown]
# ### Only using sale prices over 0:

# %%
properties = properties[properties['saleprice'] > 0]
properties
# Out:
#         excisetaxnbr major_minor  saleprice    recordingnbr volume page  \
# 9            3027422  2130430120     560000  20191226000848
# 10           3002257  9406520630     435000  20190730001339
# 27           3033993  9264902060     370000  20200214001331
# 42           3043271  5703500010     575000  20200417000249
# 50           2937935  8731780100     185000  20180625000560
# ...              ...         ...        ...             ...    ...  ...
# 351038       3025068  6150200505     745000  20191212000602
# 351040       2986698  0333100255    6500000  20190508000847
# 351041       3038910  0267700310     455000  20200317001112
# 351043       3045715  4127000898     619000  20200505001286
# 351062       2935450  2193310270     850000  20180612000762
#
#        platnbr plattype         platlot platblock  ... saleinstrument  \
# 9                                                  ...              3
# 10                                                 ...              3
# 27                                                 ...              2
# 42                                                 ...              2
# 50                                                 ...              3
# ...        ...      ...             ...       ...  ...            ...
# 351038                                             ...              3
# 351040                                             ...              3
# 351041                                             ...              2
# 351043                                             ...              2
# 351062                                             ...              3
#
#        afforestland  afcurrentuseland  afnonprofituse  afhistoricproperty  \
# 9                 N                 N               N                   N
# 10                N                 N               N                   N
# 27                N                 N               N                   N
# 42                N                 N               N                   N
# 50                N                 N               N                   N
# ...             ...               ...             ...                 ...
# 351038            N                 N               N                   N
# 351040            N                 N               N                   N
# 351041            N                 N               N                   N
# 351043            N                 N               N                   N
# 351062            N                 N               N                   N
#
#        salereason propertyclass salewarning monthsold  yrsold
# 9               1             8                  12.0  2019.0
# 10              1             8                   7.0  2019.0
# 27              1             8                   2.0  2020.0
# 42              1             8                   4.0  2020.0
# 50              1             3                   6.0  2018.0
# ...           ...           ...         ...       ...     ...
# 351038          1             8                  11.0  2019.0
# 351040          1             8                   4.0  2019.0
# 351041          1             3                   3.0  2020.0
# 351043          1             8                   4.0  2020.0
# 351062          1             8                   6.0  2018.0
#
# [47760 rows x 24 columns]

# %%
properties['saleprice'].describe()
# Out:
# count    4.776000e+04
# mean     7.446527e+05
# std      6.547413e+05
# min      5.000000e+00
# 25%      4.250000e+05
# 50%      6.180000e+05
# 75%      8.680000e+05
# max      5.300000e+07
# Name: saleprice, dtype: float64

# %% [markdown]
# ### Filtering out based on principal use:

# %%
properties['principaluse'].unique()
# Out:
# array([6, 2, 7, 0], dtype=int64)

# %% [markdown]
# According to our lookup,
#
# **6** - Residential
#
# **2** - Condominium
#
# **7** - Commercial
#
# I will only focus on residential and condo properties.

# %%
properties = properties[properties['principaluse'].isin([6,2])]
properties
# Out:
#         excisetaxnbr major_minor  saleprice    recordingnbr volume page  \
# 9            3027422  2130430120     560000  20191226000848
# 10           3002257  9406520630     435000  20190730001339
# 27           3033993  9264902060     370000  20200214001331
# 42           3043271  5703500010     575000  20200417000249
# 50           2937935  8731780100     185000  20180625000560
# ...              ...         ...        ...             ...    ...  ...
# 351038       3025068  6150200505     745000  20191212000602
# 351040       2986698  0333100255    6500000  20190508000847
# 351041       3038910  0267700310     455000  20200317001112
# 351043       3045715  4127000898     619000  20200505001286
# 351062       2935450  2193310270     850000  20180612000762
#
#        platnbr plattype         platlot platblock  ... saleinstrument  \
# 9                                                  ...              3
# 10                                                 ...              3
# 27                                                 ...              2
# 42                                                 ...              2
# 50                                                 ...              3
# ...        ...      ...             ...       ...  ...            ...
# 351038                                             ...              3
# 351040                                             ...              3
# 351041                                             ...              2
# 351043                                             ...              2
# 351062                                             ...              3
#
#        afforestland  afcurrentuseland  afnonprofituse  afhistoricproperty  \
# 9                 N                 N               N                   N
# 10                N                 N               N                   N
# 27                N                 N               N                   N
# 42                N                 N               N                   N
# 50                N                 N               N                   N
# ...             ...               ...             ...                 ...
# 351038            N                 N               N                   N
# 351040            N                 N               N                   N
# 351041            N                 N               N                   N
# 351043            N                 N               N                   N
# 351062            N                 N               N                   N
#
#        salereason propertyclass salewarning monthsold  yrsold
# 9               1             8                  12.0  2019.0
# 10              1             8                   7.0  2019.0
# 27              1             8                   2.0  2020.0
# 42              1             8                   4.0  2020.0
# 50              1             3                   6.0  2018.0
# ...           ...           ...         ...       ...     ...
# 351038          1             8                  11.0  2019.0
# 351040          1             8                   4.0  2019.0
# 351041          1             3                   3.0  2020.0
# 351043          1             8                   4.0  2020.0
# 351062          1             8                   6.0  2018.0
#
# [47404 rows x 24 columns]

# %% [markdown]
# ### Checking for 'propertyclass'

# %%
properties['propertyclass'].unique()
# Out:
# array([8, 3, 7, 9], dtype=int64)

# %% [markdown]
# The follwing values and their definitions are found in our lookup file:
#
# **7** - Res-Land only (I will remove this to only display residential property)
#
# I will keep:
#
# **8** - Residential- Improved Property
#
# **3** - Condominium
#
# **9** - Res/Condo mobile

# %%
properties = properties[properties['propertyclass'].isin([8,3,9])]
properties.head()
# Out:
#     excisetaxnbr major_minor  saleprice    recordingnbr volume page platnbr  \
# 9        3027422  2130430120     560000  20191226000848
# 10       3002257  9406520630     435000  20190730001339
# 27       3033993  9264902060     370000  20200214001331
# 42       3043271  5703500010     575000  20200417000249
# 50       2937935  8731780100     185000  20180625000560
#
#    plattype         platlot platblock  ... saleinstrument afforestland  \
# 9                                      ...              3            N
# 10                                     ...              3            N
# 27                                     ...              2            N
# 42                                     ...              2            N
# 50                                     ...              3            N
#
#     afcurrentuseland  afnonprofituse  afhistoricproperty salereason  \
# 9                  N               N                   N          1
# 10                 N               N                   N          1
# 27                 N               N                   N          1
# 42                 N               N                   N          1
# 50                 N               N                   N          1
#
#    propertyclass salewarning monthsold  yrsold
# 9              8                  12.0  2019.0
# 10             8                   7.0  2019.0
# 27             8                   2.0  2020.0
# 42             8                   4.0  2020.0
# 50             3                   6.0  2018.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Checking for duplicates based on major_minor numbers

# %%
len(properties) - len(properties.major_minor.unique())
# Out:
# 1585

# %% [markdown]
# I will check to see if there are any trends in the duplicates, since it is possible a home could have been sold more than once during the set timeframe.

# %%
properties[properties['major_minor'].isin(['8843900445','8847500000'])]
# Out:
#         excisetaxnbr major_minor  saleprice    recordingnbr volume page  \
# 41899        2975737  8843900445     815000  20190228001472
# 149957       2975141  8843900445     699900  20190226001189
# 162622       2993692  8847500000     764990  20190614000861
# 197942       2976965  8843900445     706900  20190311000874
# 210949       3020478  8847500000     698654  20191114000503
# 292126       2980974  8843900445     799900  20190405000497
# 294166       2975973  8843900445     782900  20190301000951
# 312455       2975726  8843900445     776900  20190228001436
# 332992       2976878  8847500000     784684  20190311000330
#
#        platnbr plattype         platlot platblock  ... saleinstrument  \
# 41899                                              ...              3
# 149957                                             ...              3
# 162622                                             ...              3
# 197942                                             ...              3
# 210949                                             ...              3
# 292126                                             ...              3
# 294166                                             ...              3
# 312455                                             ...              3
# 332992                                             ...              3
#
#        afforestland  afcurrentuseland  afnonprofituse  afhistoricproperty  \
# 41899             N                 N               N                   N
# 149957            N                 N               N                   N
# 162622            N                 N               N                   N
# 197942            N                 N               N                   N
# 210949            N                 N               N                   N
# 292126            N                 N               N                   N
# 294166            N                 N               N                   N
# 312455            N                 N               N                   N
# 332992            N                 N               N                   N
#
#        salereason propertyclass salewarning monthsold  yrsold
# 41899           1             8                   2.0  2019.0
# 149957          1             8                   2.0  2019.0
# 162622          1             3                   6.0  2019.0
# 197942          1             8                   3.0  2019.0
# 210949          1             3                  11.0  2019.0
# 292126          1             8                   3.0  2019.0
# 294166          1             8                   2.0  2019.0
# 312455          1             8                   2.0  2019.0
# 332992          1             3          43       3.0  2019.0
#
# [9 rows x 24 columns]

# %%
#Dropping the duplicates
properties.drop_duplicates(subset='major_minor', keep='last', inplace=True)
# Out:
# <ipython-input-19-6281fb0af3f5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties.drop_duplicates(subset='major_minor', keep='last', inplace=True)

# %%
properties.head()
# Out:
#     excisetaxnbr major_minor  saleprice    recordingnbr volume page platnbr  \
# 9        3027422  2130430120     560000  20191226000848
# 10       3002257  9406520630     435000  20190730001339
# 27       3033993  9264902060     370000  20200214001331
# 50       2937935  8731780100     185000  20180625000560
# 55       2926991  2211700075    1425000  20180427001349
#
#    plattype         platlot platblock  ... saleinstrument afforestland  \
# 9                                      ...              3            N
# 10                                     ...              3            N
# 27                                     ...              2            N
# 50                                     ...              3            N
# 55                                     ...              3            N
#
#     afcurrentuseland  afnonprofituse  afhistoricproperty salereason  \
# 9                  N               N                   N          1
# 10                 N               N                   N          1
# 27                 N               N                   N          1
# 50                 N               N                   N          1
# 55                 N               N                   N          1
#
#    propertyclass salewarning monthsold  yrsold
# 9              8                  12.0  2019.0
# 10             8                   7.0  2019.0
# 27             8                   2.0  2020.0
# 50             3                   6.0  2018.0
# 55             8                   4.0  2018.0
#
# [5 rows x 24 columns]

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45203 entries, 9 to 351062
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   excisetaxnbr        45203 non-null  int64
#  1   major_minor         45203 non-null  object
#  2   saleprice           45203 non-null  int64
#  3   recordingnbr        45203 non-null  object
#  4   volume              45203 non-null  object
#  5   page                45203 non-null  object
#  6   platnbr             45203 non-null  object
#  7   plattype            45203 non-null  object
#  8   platlot             45203 non-null  object
#  9   platblock           45203 non-null  object
#  10  sellername          45203 non-null  object
#  11  buyername           45203 non-null  object
#  12  propertytype        45203 non-null  int64
#  13  principaluse        45203 non-null  int64
#  14  saleinstrument      45203 non-null  int64
#  15  afforestland        45203 non-null  object
#  16  afcurrentuseland    45203 non-null  object
#  17  afnonprofituse      45203 non-null  object
#  18  afhistoricproperty  45203 non-null  object
#  19  salereason          45203 non-null  int64
#  20  propertyclass       45203 non-null  int64
#  21  salewarning         45203 non-null  object
#  22  monthsold           45203 non-null  float64
#  23  yrsold              45203 non-null  float64
# dtypes: float64(2), int64(7), object(15)
# memory usage: 8.6+ MB

# %%
to_drop = ['volume', 'page', 'platnbr', 'plattype', 'platlot', 'platblock', 'sellername', 'buyername']
properties.drop(to_drop, axis=1, inplace=True)
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
properties.head()
# Out:
#     excisetaxnbr major_minor  saleprice    recordingnbr  propertytype  \
# 9        3027422  2130430120     560000  20191226000848            11
# 10       3002257  9406520630     435000  20190730001339            11
# 27       3033993  9264902060     370000  20200214001331            11
# 50       2937935  8731780100     185000  20180625000560            14
# 55       2926991  2211700075    1425000  20180427001349            11
#
#     principaluse  saleinstrument afforestland afcurrentuseland afnonprofituse  \
# 9              6               3            N                N              N
# 10             6               3            N                N              N
# 27             6               2            N                N              N
# 50             2               3            N                N              N
# 55             6               3            N                N              N
#
#    afhistoricproperty  salereason  propertyclass salewarning  monthsold  \
# 9                   N           1              8                   12.0
# 10                  N           1              8                    7.0
# 27                  N           1              8                    2.0
# 50                  N           1              3                    6.0
# 55                  N           1              8                    4.0
#
#     yrsold
# 9   2019.0
# 10  2019.0
# 27  2020.0
# 50  2018.0
# 55  2018.0

# %% [markdown]
# Now I'll repeat everything I did for "properties" and apply it to residential buildings.

# %%
ResBldg.rename(columns=str.lower, inplace=True)
ResBldg['major'] = ResBldg['major'].astype(str)
ResBldg['minor'] = ResBldg['minor'].astype(str)

ResBldg['major'] = ResBldg['major'].apply(major_padded)
ResBldg['minor'] = ResBldg['minor'].apply(minor_padded)

ResBldg['major_minor'] = ResBldg['major']+ResBldg['minor']

col_name = 'major_minor'
last_col = ResBldg.pop(col_name)
ResBldg.insert(0, col_name, last_col)

ResBldg.head(2)
# Out:
#   major_minor   major minor  bldgnbr  nbrlivingunits  \
# 0  0098000720  009800  0720        1               1
# 1  0098020140  009802  0140        1               1
#
#                       address buildingnumber fraction directionprefix  \
# 0  27719  SE 26TH WAY   98075          27719                       SE
# 1  2829   277TH TER SE  98075          2829
#
#                   streetname  ... fpmultistory fpfreestanding fpadditional  \
# 0  26TH                       ...            0              0            0
# 1  277TH                      ...            0              0            0
#
#    yrbuilt  yrrenovated  pcntcomplete  obsolescence  pcntnetcondition  \
# 0     2001            0             0             0                 0
# 1     2004            0             0             0                 0
#
#    condition  addnlcost
# 0          3          0
# 1          3          0
#
# [2 rows x 51 columns]

# %%
sum(ResBldg.minor == '0000')
# Out:
# 0

# %% [markdown]
# Since residential buildings don't have condominiums (**Minor=0000**), I will be forced to drop more data.

# %%
ResBldg.loc[1]
# Out:
# major_minor                           0098020140
# major                                     009802
# minor                                       0140
# bldgnbr                                        1
# nbrlivingunits                                 1
# address               2829   277TH TER SE  98075
# buildingnumber                             2829
# fraction
# directionprefix
# streetname             277TH
# streettype                                TER
# directionsuffix                               SE
# zipcode                                    98075
# stories                                        2
# bldggrade                                     10
# bldggradevar                                   0
# sqft1stfloor                                1610
# sqfthalffloor                                  0
# sqft2ndfloor                                1400
# sqftupperfloor                                 0
# sqftunfinfull                                  0
# sqftunfinhalf                                  0
# sqfttotliving                               3010
# sqfttotbasement                                0
# sqftfinbasement                                0
# finbasementgrade                               0
# sqftgaragebasement                             0
# sqftgarageattached                           660
# daylightbasement
# sqftopenporch                                380
# sqftenclosedporch                              0
# sqftdeck                                       0
# heatsystem                                     5
# heatsource                                     2
# brickstone                                     0
# viewutilization
# bedrooms                                       4
# bathhalfcount                                  1
# bath3qtrcount                                  2
# bathfullcount                                  2
# fpsinglestory                                  3
# fpmultistory                                   0
# fpfreestanding                                 0
# fpadditional                                   0
# yrbuilt                                     2004
# yrrenovated                                    0
# pcntcomplete                                   0
# obsolescence                                   0
# pcntnetcondition                               0
# condition                                      3
# addnlcost                                      0
# Name: 1, dtype: object

# %%
ResBldg = ResBldg.dropna(how='any',axis=0)
ResBldg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154594 entries, 0 to 181506
# Data columns (total 51 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   major_minor         154594 non-null  object
#  1   major               154594 non-null  object
#  2   minor               154594 non-null  object
#  3   bldgnbr             154594 non-null  int64
#  4   nbrlivingunits      154594 non-null  int64
#  5   address             154594 non-null  object
#  6   buildingnumber      154594 non-null  object
#  7   fraction            154594 non-null  object
#  8   directionprefix     154594 non-null  object
#  9   streetname          154594 non-null  object
#  10  streettype          154594 non-null  object
#  11  directionsuffix     154594 non-null  object
#  12  zipcode             154594 non-null  object
#  13  stories             154594 non-null  float64
#  14  bldggrade           154594 non-null  int64
#  15  bldggradevar        154594 non-null  int64
#  16  sqft1stfloor        154594 non-null  int64
#  17  sqfthalffloor       154594 non-null  int64
#  18  sqft2ndfloor        154594 non-null  int64
#  19  sqftupperfloor      154594 non-null  int64
#  20  sqftunfinfull       154594 non-null  int64
#  21  sqftunfinhalf       154594 non-null  int64
#  22  sqfttotliving       154594 non-null  int64
#  23  sqfttotbasement     154594 non-null  int64
#  24  sqftfinbasement     154594 non-null  int64
#  25  finbasementgrade    154594 non-null  int64
#  26  sqftgaragebasement  154594 non-null  int64
#  27  sqftgarageattached  154594 non-null  int64
#  28  daylightbasement    154594 non-null  object
#  29  sqftopenporch       154594 non-null  int64
#  30  sqftenclosedporch   154594 non-null  int64
#  31  sqftdeck            154594 non-null  int64
#  32  heatsystem          154594 non-null  int64
#  33  heatsource          154594 non-null  int64
#  34  brickstone          154594 non-null  int64
#  35  viewutilization     154594 non-null  object
#  36  bedrooms            154594 non-null  int64
#  37  bathhalfcount       154594 non-null  int64
#  38  bath3qtrcount       154594 non-null  int64
#  39  bathfullcount       154594 non-null  int64
#  40  fpsinglestory       154594 non-null  int64
#  41  fpmultistory        154594 non-null  int64
#  42  fpfreestanding      154594 non-null  int64
#  43  fpadditional        154594 non-null  int64
#  44  yrbuilt             154594 non-null  int64
#  45  yrrenovated         154594 non-null  int64
#  46  pcntcomplete        154594 non-null  int64
#  47  obsolescence        154594 non-null  int64
#  48  pcntnetcondition    154594 non-null  int64
#  49  condition           154594 non-null  int64
#  50  addnlcost           154594 non-null  int64
# dtypes: float64(1), int64(37), object(13)
# memory usage: 61.3+ MB

# %% [markdown]
# ### Converting 'zipcode' to int

# %%
ResBldg['zipcode'] = ResBldg['zipcode'].str.split('-').str[0]
ResBldg['zipcode'].value_counts()
# Out:
# 98042    4661
# 98023    4177
# 98115    4175
# 98038    3828
# 98058    3733
#          ...
# 9800        1
# 98111       1
# 98952       1
# 98026       1
# 98132       1
# Name: zipcode, Length: 122, dtype: int64

# %%
ResBldg['zipcode'] = ResBldg['zipcode'].astype(str).str.replace(',', '')
ResBldg['zipcode'] = ResBldg['zipcode'].astype(str).str.replace(' ', '')
ResBldg['zipcode'] = ResBldg['zipcode'].astype(str).str.replace('.', '')

# %%
df = ResBldg[ResBldg['zipcode'].apply(lambda x: not x.isnumeric())]
df
# Out:
#        major_minor   major minor  bldgnbr  nbrlivingunits  \
# 71823   3126069112  312606  9112        1               1
# 173514  9828702305  982870  2305        1               1
#
#                               address buildingnumber fraction directionprefix  \
# 71823        11026   AVONDALE RD NE            11026
# 173514  111 D  26TH AVE E  A on plans          111        D
#
#                        streetname  ... fpmultistory fpfreestanding  \
# 71823   AVONDALE                   ...            0              0
# 173514  26TH                       ...            0              0
#
#        fpadditional  yrbuilt  yrrenovated  pcntcomplete  obsolescence  \
# 71823             0     2015            0             0             0
# 173514            0     2019            0            60             0
#
#         pcntnetcondition  condition  addnlcost
# 71823                  0          3       8000
# 173514                 0          3          0
#
# [2 rows x 51 columns]

# %%
#Dropping non-numeric zipcode entries
ResBldg = ResBldg.drop(index=[71823,173514])

# %%
ResBldg['zipcode'].value_counts()
# Out:
# 98042    4661
# 98023    4177
# 98115    4175
# 98038    3828
# 98058    3756
#          ...
# 98012       1
# 98088       1
# 95059       1
# 98101       1
# 9059        1
# Name: zipcode, Length: 119, dtype: int64

# %%
ResBldg['zipcode']= ResBldg['zipcode'].astype(np.int64)

# %%
prop_res = properties.merge(ResBldg, on='major_minor', suffixes=("", " "))
prop_res.describe()
# Out:
#        excisetaxnbr     saleprice  propertytype  principaluse  saleinstrument  \
# count  3.392800e+04  3.392800e+04  33928.000000       33928.0    33928.000000
# mean   2.987995e+06  7.676240e+05     11.024228           6.0        3.073450
# std    3.762621e+04  5.874356e+05      0.280116           0.0        2.185849
# min    2.909403e+06  5.000000e+00     11.000000           6.0        2.000000
# 25%    2.956618e+06  4.500000e+05     11.000000           6.0        3.000000
# 50%    2.992006e+06  6.450000e+05     11.000000           6.0        3.000000
# 75%    3.019295e+06  8.850000e+05     11.000000           6.0        3.000000
# max    3.050093e+06  2.675000e+07     18.000000           6.0       27.000000
#
#          salereason  propertyclass     monthsold        yrsold       bldgnbr  \
# count  33928.000000        33928.0  33928.000000  33928.000000  33928.000000
# mean       1.014914            8.0      6.396781   2018.826839      1.008872
# std        0.501786            0.0      3.174764      0.708859      0.113924
# min        1.000000            8.0      1.000000   2018.000000      1.000000
# 25%        1.000000            8.0      4.000000   2018.000000      1.000000
# 50%        1.000000            8.0      6.000000   2019.000000      1.000000
# 75%        1.000000            8.0      9.000000   2019.000000      1.000000
# max       18.000000            8.0     12.000000   2020.000000      7.000000
#
#        ...  fpmultistory  fpfreestanding  fpadditional       yrbuilt  \
# count  ...  33928.000000    33928.000000  33928.000000  33928.000000
# mean   ...      0.337921        0.078961      0.198744   1968.021752
# std    ...      0.512201        0.280399      0.418317     28.385749
# min    ...      0.000000        0.000000      0.000000   1900.000000
# 25%    ...      0.000000        0.000000      0.000000   1950.000000
# 50%    ...      0.000000        0.000000      0.000000   1969.000000
# 75%    ...      1.000000        0.000000      0.000000   1990.000000
# max    ...      5.000000        3.000000      3.000000   2020.000000
#
#         yrrenovated  pcntcomplete  obsolescence  pcntnetcondition  \
# count  33928.000000  33928.000000  33928.000000      33928.000000
# mean     110.160133      0.173898      0.110410          0.006425
# std      456.266456      3.498123      2.103985          0.457740
# min        0.000000      0.000000      0.000000          0.000000
# 25%        0.000000      0.000000      0.000000          0.000000
# 50%        0.000000      0.000000      0.000000          0.000000
# 75%        0.000000      0.000000      0.000000          0.000000
# max     2020.000000    100.000000     99.000000         43.000000
#
#           condition     addnlcost
# count  33928.000000  33928.000000
# mean       3.536401    597.927995
# std        0.718633   2286.108745
# min        1.000000      0.000000
# 25%        3.000000      0.000000
# 50%        3.000000      0.000000
# 75%        4.000000      0.000000
# max        5.000000  50000.000000
#
# [8 rows x 48 columns]

# %% [markdown]
# ### Converting the 'yrrenovated' column to a binary
# Next, the 'yrrenovated' column has a large amount zero values (denoting that a house hasn't been renovated). Rather than dropping the data, I will make this a binary column whether a house was sold within 10 years of a renovation or not, or built within the last five years.
#
# First, I will make a new column 'age' with the properties' ages as variables to get a better sense of how old a home is.

# %%
#Convert YrBuilt to age by subtracting the build year from the most recent year in the in dataframe
prop_res['age'] = 2020 - prop_res.yrbuilt

# %% [markdown]
# Now I will convert the 'yrrenovated' column to a binary column.

# %%
prop_res['yrrenovated'].value_counts()
# Out:
# 0       32059
# 2018      173
# 2019      122
# 2017       66
# 2003       58
#         ...
# 1935        1
# 1949        1
# 1944        1
# 1952        1
# 1936        1
# Name: yrrenovated, Length: 80, dtype: int64

# %%
prop_res['yrrenovated'].fillna(0.0, inplace=True)

# %%
prop_res['renovated'] = prop_res['yrsold'] - prop_res['yrrenovated']

# %%
#Replacing values less than 10 with 1, and values over 10 with 0
Renovated = prop_res.renovated.values
Age = prop_res.age.values
values = np.where(Renovated <= 10, 1, 0)
prop_res['renovated'] = np.where(Age <= 5, 1, values)

# %% [markdown]
# Now I'll check again for duplicates:

# %%
prop_res.major_minor.value_counts()
# Out:
# 6373000170    5
# 0809003030    5
# 2822059059    4
# 7129303601    4
# 1962200005    4
#              ..
# 7424000080    1
# 3904921000    1
# 1822069116    1
# 9211500090    1
# 4197400123    1
# Name: major_minor, Length: 33671, dtype: int64

# %%
prop_res[prop_res['major_minor'].isin(['0809003030', '6373000170', '2822059059'])]
# Out:
#        excisetaxnbr major_minor  saleprice    recordingnbr  propertytype  \
# 1886        3048606  0809003030    1176000  20200527001133            11
# 1887        3048606  0809003030    1176000  20200527001133            11
# 1888        3048606  0809003030    1176000  20200527001133            11
# 1889        3048606  0809003030    1176000  20200527001133            11
# 1890        3048606  0809003030    1176000  20200527001133            11
# 24272       2921369  6373000170    1500000  20180328000779            11
# 24273       2921369  6373000170    1500000  20180328000779            11
# 24274       2921369  6373000170    1500000  20180328000779            11
# 24275       2921369  6373000170    1500000  20180328000779            11
# 24276       2921369  6373000170    1500000  20180328000779            11
# 24803       2933171  2822059059     825000  20180531000805            11
# 24804       2933171  2822059059     825000  20180531000805            11
# 24805       2933171  2822059059     825000  20180531000805            11
# 24806       2933171  2822059059     825000  20180531000805            11
#
#        principaluse  saleinstrument afforestland afcurrentuseland  \
# 1886              6               3            N                N
# 1887              6               3            N                N
# 1888              6               3            N                N
# 1889              6               3            N                N
# 1890              6               3            N                N
# 24272             6               3            N                N
# 24273             6               3            N                N
# 24274             6               3            N                N
# 24275             6               3            N                N
# 24276             6               3            N                N
# 24803             6               3            N                N
# 24804             6               3            N                N
# 24805             6               3            N                N
# 24806             6               3            N                N
#
#       afnonprofituse  ... fpadditional  yrbuilt  yrrenovated pcntcomplete  \
# 1886               N  ...            0     2019            0           40
# 1887               N  ...            0     2019            0           40
# 1888               N  ...            0     2019            0           40
# 1889               N  ...            0     2019            0           40
# 1890               N  ...            0     2019            0           40
# 24272              N  ...            0     2019            0           60
# 24273              N  ...            0     2019            0           60
# 24274              N  ...            0     2019            0           60
# 24275              N  ...            0     2019            0           60
# 24276              N  ...            0     2019            0           60
# 24803              N  ...            1     1949            0            0
# 24804              N  ...            0     1924            0            0
# 24805              N  ...            0     1934         2010            0
# 24806              N  ...            0     1981            0            0
#
#        obsolescence  pcntnetcondition condition addnlcost  age  renovated
# 1886              0                 0         3         0    1          1
# 1887              0                 0         3         0    1          1
# 1888              0                 0         3         0    1          1
# 1889              0                 0         3         0    1          1
# 1890              0                 0         3         0    1          1
# 24272             0                 0         3         0    1          1
# 24273             0                 0         3         0    1          1
# 24274             0                 0         3         0    1          1
# 24275             0                 0         3         0    1          1
# 24276             0                 0         3         0    1          1
# 24803             0                 0         4         0   71          0
# 24804             5                 0         4         0   96          0
# 24805             0                 0         3         0   86          1
# 24806             0                 0         3         0   39          0
#
# [14 rows x 68 columns]

# %%
prop_res.drop_duplicates(subset='major_minor', inplace=True)
len(prop_res)
# Out:
# 33671

# %% [markdown]
# We are now left with 33,671 entries in our data frame.

# %% [markdown]
# ### Now for our last file, 'Parcel':

# %%
Parcel.rename(columns=str.lower, inplace=True)
Parcel['major'] = Parcel['major'].astype(str)
Parcel['minor'] = Parcel['minor'].astype(str)
Parcel['major'] = Parcel['major'].apply(major_padded)
Parcel['minor'] = Parcel['minor'].apply(minor_padded)
Parcel['major_minor'] = Parcel['major']+Parcel['minor']
last_col = Parcel.pop(col_name)
Parcel.insert(0, col_name, last_col)

# %%
prop_res = prop_res.merge(Parcel, on='major_minor', suffixes=("", " "))

# %%
prop_res.shape
# Out:
# (33671, 150)

# %%
prop_res['proptype'].unique()
# Out:
# array(['R'], dtype=object)

# %% [markdown]
# Thankfully, we haven't lost any more entries *and* our property type column only contains 'R' (residential) values.

# %%
prop_res.describe()
# Out:
#        excisetaxnbr     saleprice  propertytype  principaluse  saleinstrument  \
# count  3.367100e+04  3.367100e+04  33671.000000       33671.0     33671.00000
# mean   2.987987e+06  7.654065e+05     11.023908           6.0         3.07110
# std    3.760185e+04  5.794149e+05      0.280319           0.0         2.17568
# min    2.909403e+06  5.000000e+00     11.000000           6.0         2.00000
# 25%    2.956624e+06  4.500000e+05     11.000000           6.0         3.00000
# 50%    2.992018e+06  6.450000e+05     11.000000           6.0         3.00000
# 75%    3.018590e+06  8.840000e+05     11.000000           6.0         3.00000
# max    3.050093e+06  2.675000e+07     18.000000           6.0        27.00000
#
#          salereason  propertyclass     monthsold        yrsold       bldgnbr  \
# count  33671.000000        33671.0  33671.000000  33671.000000  33671.000000
# mean       1.015028            8.0      6.402958   2018.826141      1.003772
# std        0.503696            0.0      3.172576      0.708517      0.071995
# min        1.000000            8.0      1.000000   2018.000000      1.000000
# 25%        1.000000            8.0      4.000000   2018.000000      1.000000
# 50%        1.000000            8.0      6.000000   2019.000000      1.000000
# 75%        1.000000            8.0      9.000000   2019.000000      1.000000
# max       18.000000            8.0     12.000000   2020.000000      7.000000
#
#        ...  wfntpoorquality  wfntrestrictedaccess  tidelandshoreland  \
# count  ...     33671.000000          33671.000000       33671.000000
# mean   ...         0.000713              0.005554           0.015117
# std    ...         0.026689              0.108990           0.172277
# min    ...         0.000000              0.000000           0.000000
# 25%    ...         0.000000              0.000000           0.000000
# 50%    ...         0.000000              0.000000           0.000000
# 75%    ...         0.000000              0.000000           0.000000
# max    ...         1.000000              3.000000           3.000000
#
#        lotdepthfactor  trafficnoise  airportnoise  nbrbldgsites  \
# count    33671.000000  33671.000000       33671.0   33671.00000
# mean         0.049004      0.207270           0.0       0.00689
# std          2.031641      0.554123           0.0       0.14849
# min          0.000000      0.000000           0.0       0.00000
# 25%          0.000000      0.000000           0.0       0.00000
# 50%          0.000000      0.000000           0.0       0.00000
# 75%          0.000000      0.000000           0.0       0.00000
# max        109.000000      3.000000           0.0      16.00000
#
#        contamination  historicsite  currentusedesignation
# count        33671.0  33671.000000           33671.000000
# mean             0.0      0.001277               0.002762
# std              0.0      0.060917               0.087662
# min              0.0      0.000000               0.000000
# 25%              0.0      0.000000               0.000000
# 50%              0.0      0.000000               0.000000
# 75%              0.0      0.000000               0.000000
# max              0.0      3.000000               3.000000
#
# [8 rows x 94 columns]

# %% [markdown]
# **I will select features of a residential property that I believe would have a bearing on its saleprice:**

# %%
property_data = prop_res.loc[:, ['saleprice', 'sqfttotliving', 'yrbuilt', 'yrrenovated', 'bedrooms',
                      'zipcode', 'sqfttotbasement', 'sqftfinbasement', 'sqftopenporch',
                      'sqftenclosedporch', 'sqftdeck','heatsystem', 'bathhalfcount', 
                      'bath3qtrcount', 'bathfullcount','condition','sqftgarageattached',
                      'bldggrade', 'finbasementgrade', 'inadequateparking', 'township','trafficnoise']]

# %%
property_data.head()
# Out:
#    saleprice  sqfttotliving  yrbuilt  yrrenovated  bedrooms  zipcode  \
# 0     560000           1930     1989            0         3    98019
# 1     435000           1975     1994            0         3    98038
# 2     370000           1750     1979            0         3    98023
# 3    1425000           2850     1985            0         4    98006
# 4    1085000           1870     2008            0         3    98102
#
#    sqfttotbasement  sqftfinbasement  sqftopenporch  sqftenclosedporch  ...  \
# 0                0                0            180                  0  ...
# 1                0                0             45                  0  ...
# 2             1130              460              0                  0  ...
# 3                0                0            190                  0  ...
# 4              790              790              0                  0  ...
#
#    bathhalfcount  bath3qtrcount  bathfullcount  condition  sqftgarageattached  \
# 0              0              0              2          3                 550
# 1              0              2              1          3                 465
# 2              0              0              2          3                 180
# 3              1              0              2          4                 420
# 4              1              0              2          3                 230
#
#    bldggrade  finbasementgrade  inadequateparking  township  trafficnoise
# 0          7                 0                  0        26             0
# 1          7                 0                  0        22             0
# 2          8                 6                  2        21             0
# 3          9                 0                  0        24             0
# 4          8                 8                  2        25             0
#
# [5 rows x 22 columns]

# %% [markdown]
# And lastly, I will narrow down the total square foot living space to 4500 (anything more is either a massive mansion or not a single family home, both of which are outside the scope of this analysis) and filter out properties between 10 and 2.5 million.

# %%
property_data = property_data[property_data['sqfttotliving'] < 4500]

# %%
property_data = property_data[(property_data['saleprice'] < 2500000) & (property_data['saleprice'] > 10)]

# %%
property_data.shape
# Out:
# (32732, 22)

# %%
cleaned_data = property_data.to_csv('cleaned_data.csv')
property_data = prop_res.to_csv('property_data.csv')

# %% [markdown]
# # Investigating the Target Variable: 'saleprice'

# %%
kc_data = pd.read_csv('../../data/processed/cleaned_data.csv', index_col=0) #Load w/out the unnecessary 'Unnamed:0' column.
kc_data.head()
# Out:
#    saleprice  sqfttotliving  yrbuilt  yrrenovated  bedrooms  zipcode  \
# 0     560000           1930     1989            0         3    98019
# 1     435000           1975     1994            0         3    98038
# 2     370000           1750     1979            0         3    98023
# 3    1425000           2850     1985            0         4    98006
# 4    1085000           1870     2008            0         3    98102
#
#    sqfttotbasement  sqftfinbasement  sqftopenporch  sqftenclosedporch  ...  \
# 0                0                0            180                  0  ...
# 1                0                0             45                  0  ...
# 2             1130              460              0                  0  ...
# 3                0                0            190                  0  ...
# 4              790              790              0                  0  ...
#
#    bathhalfcount  bath3qtrcount  bathfullcount  condition  sqftgarageattached  \
# 0              0              0              2          3                 550
# 1              0              2              1          3                 465
# 2              0              0              2          3                 180
# 3              1              0              2          4                 420
# 4              1              0              2          3                 230
#
#    bldggrade  finbasementgrade  inadequateparking  township  trafficnoise
# 0          7                 0                  0        26             0
# 1          7                 0                  0        22             0
# 2          8                 6                  2        21             0
# 3          9                 0                  0        24             0
# 4          8                 8                  2        25             0
#
# [5 rows x 22 columns]

# %%
kc_data.shape
# Out:
# (32732, 22)

# %%
kc_data.saleprice.describe()
# Out:
# count    3.273200e+04
# mean     7.090310e+05
# std      3.638994e+05
# min      1.000000e+02
# 25%      4.450000e+05
# 50%      6.300000e+05
# 75%      8.600000e+05
# max      2.499888e+06
# Name: saleprice, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.set_title('Histogram of 2018, 2019, & 2020 Sales Price Data', fontsize = 12)
sns.histplot(kc_data.saleprice, ax = ax)
ax.tick_params(axis='both', labelsize=10)
plt.xlabel('Sale Price', fontsize = 10)
plt.ylabel('Count', fontsize = 10)
plt.savefig('../../reports/figures/visual1.png')
plt.tight_layout()

# %% [markdown]
# The filtered sales price data is right skewed which is to be expected since houses worth over 2.5 million dollars are included in the data. We see that our mean house price is just over 700K at $709,031.

# %%
data_corr = kc_data.corr()

# inspecting correlations with 'saleprice' in descending order to review the highest correlations first
sorted_corrs = data_corr['saleprice'].sort_values(ascending = False)
sorted_corrs
# Out:
# saleprice             1.000000
# bldggrade             0.602441
# sqfttotliving         0.582776
# township              0.469307
# bathfullcount         0.285041
# bedrooms              0.269357
# sqfttotbasement       0.259356
# sqftfinbasement       0.250262
# finbasementgrade      0.235648
# sqftdeck              0.215990
# sqftopenporch         0.189520
# bathhalfcount         0.182185
# bath3qtrcount         0.175900
# heatsystem            0.164649
# yrrenovated           0.119026
# sqftgarageattached    0.103858
# inadequateparking     0.039884
# sqftenclosedporch     0.010737
# yrbuilt               0.005304
# trafficnoise          0.003980
# zipcode              -0.002015
# condition            -0.002719
# Name: saleprice, dtype: float64

# %% [markdown]
# The top 2 highest correlated features with 'saleprice' are 'bldggrade' and 'sqfttotliving'. As is to be expected, houses with larger square footage are more expensive than smaller square foot houses. I will start by investigating this feature and work on building my first model.

# %% [markdown]
# ## Total Living Square Footage ('sqfttotliving')
# I'll start by examining the relationship between total living square footage and sale price.

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.regplot(x = 'sqfttotliving', y = 'saleprice', data = kc_data,
            scatter_kws={"color": "#0055AA"}, line_kws={"color": "green"});
ax.set_title('Scatter Plot of Total Living Square Footage against Sale Price', fontsize = 20)
ax.tick_params(axis='both', labelsize=15)
plt.xlabel('Total Living Square Footage', fontsize = 15)
plt.ylabel('Sale Price (Hundred Thousands)', fontsize = 15)
plt.savefig('../../reports/figures/visual2.png')
plt.tight_layout()

# %% [markdown]
# We can see there is a fairly strong correlation between total living space and sale price.
# Let's examine the distribution of sqfttotliving:

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.title('Distribution of Total Living Space', fontsize = 12)
sns.histplot(kc_data.sqfttotliving, ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Living Space Square Foot', fontsize = 10)
plt.savefig('../../reports/figures/visual3.png')
plt.tight_layout()

# %% [markdown]
# I will log-transform the data and examine, since this appears to be slightly right-skewed.

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.title('Log-Transformed Distribution of Total Living Square Foot', fontsize = 12)
sns.histplot(np.log(kc_data.sqfttotliving), ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Living Square Footage', fontsize = 10)
plt.savefig('../../reports/figures/visual4.png')
plt.tight_layout()

# %% [markdown]
# The transformation happened to skew it to the left, I will try a square root transformation:

# %%
fig, ax = plt.subplots(figsize=(8,5))
plt.title('Square Root-Transformed Distribution of Total Living Square Footage ', fontsize = 12)
sns.histplot(np.sqrt(kc_data.sqfttotliving), ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Living Square Footage', fontsize = 10)
plt.savefig('../../reports/figures/visual5.png')
plt.tight_layout()

# %% [markdown]
# There! Now the distribution is fairly normal and should work for modeling.
#
# I'll save this as a column to use later:

# %%
kc_data['sqrt_sqfttotliving'] = np.sqrt(kc_data.sqfttotliving)

# %% [markdown]
# # First Model: saleprice ~ sqfttotliving

# %%
def model(features_lst, df, target_var):
    
    # Creating a df with only the target and the chosen corellation feature
    df_model = df[features_lst]

    #R-style formula
    target = target_var
    features_lstcopy = features_lst.copy()
    features_lstcopy.remove(target)
    x_vals = features_lstcopy
    x_formula = '+'.join(x_vals)
    formula = target + '~' + x_formula

    # Fitting the model on the df composed of the two features
    model = ols(formula=formula, data=df_model).fit()
    
    print(model.summary())
    # view r^2 and model summary:
    
    return model

# %%
model_1features = ['saleprice', 'sqrt_sqfttotliving']

# %%
model1 = model(model_1features, kc_data, 'saleprice')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.320
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                 1.539e+04
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):               0.00
# Time:                        12:02:45   Log-Likelihood:            -4.5926e+05
# No. Observations:               32732   AIC:                         9.185e+05
# Df Residuals:                   32730   BIC:                         9.185e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept          -3.304e+05   8540.234    -38.683      0.000   -3.47e+05   -3.14e+05
# sqrt_sqfttotliving  2.382e+04    192.009    124.069      0.000    2.34e+04    2.42e+04
# ==============================================================================
# Omnibus:                     6894.102   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18443.352
# Skew:                           1.135   Prob(JB):                         0.00
# Kurtosis:                       5.893   Cond. No.                         229.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Our first simple model has produced an $R^2$ of 0.32. The p-value for the sqrt_sqfttotliving coefficient is 0, which indicates there is significant evidence to suggest that total living square footage does  in fact have an impact on sales price. As we've examined previously, total living square footage *is* linear with sales price, but I'll investigate the other assumptions of linear regression:

# %% [markdown]
# ## Diagnostic Summary: Normality and Homoscedasticity Assumptions

# %%
def model_diagnosis(model, x, x_name, y):
    
    residuals = model.resid
    
    fig = plt.figure()
    fig, axes = plt.subplots(nrows = 1, ncols = 3, sharex=False, sharey = False, figsize=(65,20), squeeze=False)
    
    fig.text(s="Summary of Model Diagnosis", x=.40, y=1.15, fontsize=50)
    fig.text(s="r-Squared: {r}".format(r=round(model.rsquared, 2)), x=.40, y=1.05, fontsize=40)
    fig.text(s="p-value: {p}".format(p= model.f_pvalue), x=.53, y=1.05, fontsize=40)
    
    fig.text(s='Residuals Histogram', x=.45, y=.93, fontsize=45)
    
    sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True, ax=axes[0][0])    
    plt.show;
    
    fig.text(s='QQ Plot', x=.20, y=.93, fontsize=45)
    
    axes[0][1].hist(residuals)
    plt.show;
    
    sns.residplot(x, y, ax=axes[0][2])
 
    fig.text(s='Residuals vs {x}'.format(x=x_name), x=.73, y=.93, fontsize=45)
    plt.tight_layout;
    plt.show;

# %%
sqfttotliving = kc_data['sqfttotliving']
saleprice = kc_data['saleprice']
fig = 'saleprice ~ sqfttotliving'
sqfttotliving_model = smf.ols(formula=fig, data=kc_data).fit()
model_diagnosis(sqfttotliving_model, sqfttotliving, 'Sqfttotliving', saleprice)
plt.savefig('../../reports/figures/visual6.png')
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Residuals:
# Since the residuals are hugging the line in the middle but moving away at the tails, we can determine this violates the assumption of normality. The sharp incline at the top is likely a result of the right skewed data of our sales price.
#
# #### Homoscedasticity:
# For a first model, I am hopeful looking at these results. However, due to the cone shape and fanning outwards as x gets larger, I would say that this model violates the homoscedasticity assumption.
# At the risk of losing more data, I may consider narrowing the price range a bit further.

# %% [markdown]
# ## Model Iterations: Adding More Features

# %% [markdown]
# To start adding more features to the model model, I'll look at the features with correlations with sale price greater than 0.2:

# %%
sorted_corrs[sorted_corrs > 0.2]
# Out:
# saleprice           1.000000
# bldggrade           0.602441
# sqfttotliving       0.582776
# township            0.469307
# bathfullcount       0.285041
# bedrooms            0.269357
# sqfttotbasement     0.259356
# sqftfinbasement     0.250262
# finbasementgrade    0.235648
# sqftdeck            0.215990
# Name: saleprice, dtype: float64

# %% [markdown]
# I can make the following determinations based on this list:
#
# -The square footage of decks is slightly correlated
#
# -The square footage of a basement (finished or not) has some relevance
#
# -The number of bathrooms has more relevance than the number of bedrooms
#
# -The township is important (**location, location, location!**)
#
# -The quality of the home (the grade) is most important.
#
# I'll start by investigating highly correlated features that are directly connected to the house: total square footage, bathrooms and the porches. It should also be noted to avoid adding in extra sq footage, I won't add in basement features (real estate standard practice is that the total living square footage includes finished and unfinished basements)

# %% [markdown]
# ### Bathroom count
# I've examined that full bathroom count was highly correlated, however we have columns for the counts of half bath and three quater baths. Bathrooms are defined in real estate as as:
#
# A half bath (or powder room) is considered a bathroom with only a toilet and sink with no tub or shower
#
# A 3/4 bath is considered a bathroom with a toilet and shower with no tub
#
# A full bath is considered a bathroom with a toilet, shower *and* tub.
#
# I will calculate the total number of bathrooms per house for better understanding as follows:

# %%
kc_data['bathtotcount'] = kc_data['bathfullcount'] + (0.75 * kc_data['bath3qtrcount']) + (0.5 * kc_data['bathhalfcount'])

# %%
#I'll remove any homes that don't have a bathroom count:
kc_data = kc_data[kc_data['bathtotcount'] > 0]

# %%
#Visualizing the linear relationship between total bathroom count and sale price:
fig, ax = plt.subplots(figsize=(8,5))
sns.regplot(x = 'bathtotcount', y = 'saleprice', 
            data = kc_data, scatter_kws={"color": "#088A29"}, line_kws={"color": "darkblue"});
ax.set_title('Bathroom Count Vs. Sale Price Scatter Plot', fontsize = 12)
ax.tick_params(axis='both', labelsize=10)
plt.xlabel('Number of Bathrooms', fontsize = 10)
plt.ylabel('Sale Price', fontsize = 10)
plt.savefig('../../reports/figures/visual7.png')
plt.tight_layout()

# %%
#Checking the distribution
fig, ax = plt.subplots(figsize=(8,5))
plt.title('Distribution of Bathroom Count', fontsize = 12)
sns.distplot(kc_data.bathtotcount, ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Bathroom Count', fontsize = 10)
plt.savefig('../../reports/figures/visual8.png')
plt.tight_layout()
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# This data looks somewhat normal but right skewed, so I will see what a log transformation would do since removing all properties with no bathrooms.

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.title('Distribution of Log Transformed Bathroom Count', fontsize = 12)
sns.distplot(np.log(kc_data.bathtotcount), ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Bathroom Count', fontsize = 10)
plt.savefig('../../reports/figures/visual9.png')
plt.tight_layout()
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# This seems to have skewed the data a bit more to the left. The data is multimodal (a distribution where there are many values or bins that contain more data than other nearby bins, usually separated by gaps) the distribution most likely won't improve much with a sqrt transformation.

# %% [markdown]
# ###  Enclosed Porch Square Footage
# There two columns relating to porch square footage, and for the purpose of this analysis we will focus only on the enclosed porch column. I'll examine the relationship it has with sale price below:

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = 'sqftenclosedporch', y = 'saleprice', data = kc_data, scatter_kws={"color": "#088A29"},
            line_kws={"color": "darkblue"});
ax.set_title('Porch Square Footage Vs Sale Price Scatter Plot', fontsize = 12)
ax.tick_params(axis='both', labelsize=10)
plt.xlabel('Porch Square Footage', fontsize = 10)
plt.ylabel('Sale Price', fontsize = 10)
plt.savefig('../../reports/figures/visual10.png')
plt.tight_layout()

# %% [markdown]
# There seems to be a  very mild linear relationship here between enclosed porch sizes and sale prices,  however since there are a lot of '0' values included, the relationship is likely being affected.
#
# I'll visualize the distribution of the enclosed porch data:

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.title('Enclosed Porch Square footage', fontsize = 12)
sns.distplot(kc_data.sqftenclosedporch, ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Enclosed Porch Square Footage', fontsize = 10)
plt.savefig('../../reports/figures/visual11.png')
plt.tight_layout();
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is incredibly right skewed and due to a large number of '0' values in the data, a log transformation will not be feasible. Instead, I will try a sqrt transformation to see if it normalizes our data at all:

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.title('Square Root Transformed Enclosed Porch Square Footage', fontsize = 12)
sns.histplot(np.sqrt(kc_data.sqftenclosedporch), ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Porch Square Footage', fontsize = 10)
plt.savefig('../../reports/figures/visual12.png')
plt.tight_layout()

# %% [markdown]
# The data has not changed, so I will model using the sqrt data:

# %%
kc_data['sqrt_enclosedporch'] = np.sqrt(kc_data.sqftenclosedporch)
# Out:
# <ipython-input-78-79887bf97711>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kc_data['sqrt_enclosedporch'] = np.sqrt(kc_data.sqftenclosedporch)

# %% [markdown]
# ## Second Model: saleprice ~ sqfttotliving + bathtotcount + sqrt_enclosedporch
# Since I've investigated each feature in more detail and have determined they all have a linear relationship with saleprice, I will see if they improve the model by visualizing any multicollinearity that may exist between the features:

# %%
def heatmap_multi(x_features, df):
    """
    Creates a heatmap to show multicollinearity of all the x features in a model
    x_features (list):  A list of strings of the column names of the x features
    df:  the dataframe where the features are located
    Returns the plotted heatmap
    """
    df_x_feats = df.loc[:, x_features]

    x_corrs = df_x_feats.corr()

    fig, ax = plt.subplots(figsize = (10, 6))
    sns.heatmap(x_corrs, mask = None, vmax = 0.3, 
            center = 0, square = True, linewidths = 0.5, 
            cbar_kws = {'shrink': 0.8}, cmap='Reds', annot=True)
    ax.tick_params(axis='both', which='major', labelsize=10, labelrotation = 45)
    ax.set_title('Heat Map of Feature Multicollinearity', fontsize = 12)
    
    return plt.show()

# %%
model_features = ['saleprice', 'sqrt_sqfttotliving', 'bathtotcount', 'sqrt_enclosedporch']
#Creating x_features:
x_features = model_features.copy()
x_features.remove('saleprice')
heatmap_multi(x_features, kc_data)
plt.savefig('../../reports/figures/visual13.png')

# %% [markdown]
# Two features are highly correlate, however the maximium correlation value is 0.3 on the scale, so they have a 0.3 correlation only, which doesn't mean multicollinearity. Continuing with the model:

# %%
model2= model(model_features, kc_data, 'saleprice')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.321
# Method:                 Least Squares   F-statistic:                     5161.
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):               0.00
# Time:                        12:02:54   Log-Likelihood:            -4.5908e+05
# No. Observations:               32722   AIC:                         9.182e+05
# Df Residuals:                   32718   BIC:                         9.182e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           -3.26e+05   8837.040    -36.895      0.000   -3.43e+05   -3.09e+05
# sqrt_sqfttotliving  2.289e+04    288.986     79.212      0.000    2.23e+04    2.35e+04
# bathtotcount        1.645e+04   3526.508      4.666      0.000    9542.204    2.34e+04
# sqrt_enclosedporch  4965.0319    692.253      7.172      0.000    3608.191    6321.873
# ==============================================================================
# Omnibus:                     6860.852   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18287.299
# Skew:                           1.131   Prob(JB):                         0.00
# Kurtosis:                       5.880   Cond. No.                         239.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The $R^2$ value increased slightly from 0.320 to 0.321, and our p-values are 0. I'll check the assumptions:

# %% [markdown]
# ### Normality Assumption:

# %%
def normality_assumption(model):
    fig, ax = plt.subplots(figsize = (10, 6))
    figure = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True, ax = ax);
    ax.set_title('Residuals QQ-Plot', fontsize = 12)
    return plt.show()

# %%
normality_assumption(model2)
plt.savefig('../../reports/figures/visual14.png')

# %% [markdown]
# The plot is still very similar to before.

# %% [markdown]
# ## Homoscedasticity

# %%
def homoscedasticity(model, df):
    fig, ax = plt.subplots(figsize = (10, 6))
    plt.scatter(model.predict(), model.resid)
    sns.set(font_scale = 1)
    fig.suptitle(' Model Predictions vs. Residuals Scatter Plot', fontsize = 12)
    plt.xlabel('Model Predictions', fontsize = 10)
    plt.ylabel('Model Residuals', fontsize = 10)
    ax.tick_params(labelsize=10)
    plt.plot(model.predict(), [0 for i in range(len(df))], color = 'darkblue')
    return plt.show()

# %%
homoscedasticity(model2, kc_data)
plt.savefig('../../reports/figures/visual15.png')

# %% [markdown]
# This has a very similar cone-like shape as our first model, though the residuals are still scattered about either side of zero. Again, the homoscedasticity assumption is not met.
#
# I'll continue with adding features to see if I can yield better results.

# %% [markdown]
# ## Model 3: saleprice ~ sqrt_totlivingsqft + bathtotcount + sqrt_porch_size + sqftdeck

# %% [markdown]
# ### The Relationship Between Deck Square Footage and Sale Prices

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = 'sqftdeck', y = 'saleprice', 
            data = kc_data, scatter_kws={"color": "#088A29"}, line_kws={"color": "darkblue"});
ax.set_title('Deck Square Footage Vs. Sale Price Scatter Plot', fontsize = 12)
ax.tick_params(axis='both', labelsize=10)
plt.xlabel('Deck Square Footage', fontsize = 10)
plt.ylabel('Sale Price', fontsize = 10)
plt.savefig('../../reports/figures/visual16.png')
plt.tight_layout()

# %% [markdown]
# As with the porch feature, 0 sqft values are affecting the linearity. However, it is still a fairly linear relationship with saleprice, and we don't have any extreme outliers. I'll have a look at the distribution and if need be, the sqrt transformed distribution as well.

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.title('Deck Square Footage', fontsize = 12)
sns.distplot(kc_data.sqftdeck, ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Deck Square Footage', fontsize = 10)
plt.savefig('../../reports/figures/visual17.png')
plt.tight_layout()
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.title('Sqrt Transformed Deck Square Footage', fontsize = 12)
sns.distplot(np.sqrt(kc_data.sqftdeck), ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Deck Square Footage', fontsize = 10)
plt.savefig('../../reports/figures/visual18.png')
plt.tight_layout()
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The bulk of the data seems to have normalized a bit though the 0 values are adversely affecting it. I will create a column for this data so we can use it in our model.

# %%
kc_data['sqrt_deck_sqft'] = np.sqrt(kc_data.sqftdeck)
# Out:
# <ipython-input-89-3d0d0ed1da61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kc_data['sqrt_deck_sqft'] = np.sqrt(kc_data.sqftdeck)

# %%
model_features3 = ['saleprice', 'sqrt_sqfttotliving', 'bathtotcount', 'sqrt_enclosedporch', 'sqrt_deck_sqft']
# create x-features:
x_feats3 = model_features3.copy()
x_feats3.remove('saleprice')
heatmap_multi(x_feats3, kc_data)
plt.savefig('../../reports/figures/visual19.png')

# %%
model3 = model(model_features3, kc_data, 'saleprice')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     3917.
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):               0.00
# Time:                        12:02:59   Log-Likelihood:            -4.5902e+05
# No. Observations:               32722   AIC:                         9.181e+05
# Df Residuals:                   32717   BIC:                         9.181e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept          -3.168e+05   8858.751    -35.757      0.000   -3.34e+05   -2.99e+05
# sqrt_sqfttotliving  2.238e+04    292.031     76.628      0.000    2.18e+04     2.3e+04
# bathtotcount        1.492e+04   3522.440      4.235      0.000    8011.942    2.18e+04
# sqrt_enclosedporch  4890.0399    690.964      7.077      0.000    3535.725    6244.355
# sqrt_deck_sqft      2179.8661    194.019     11.235      0.000    1799.581    2560.151
# ==============================================================================
# Omnibus:                     6862.950   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18334.495
# Skew:                           1.131   Prob(JB):                         0.00
# Kurtosis:                       5.886   Cond. No.                         244.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The $R^2$ value again increased from 0.321 to 0.324 and p-values for each coefficient remain at 0. Let's check the assumptions:

# %% [markdown]
# ### Normality and Homoscedasticity

# %%
normality_assumption(model3)
plt.savefig('../../reports/figures/visual20.png')

# %%
homoscedasticity(model3, kc_data)
plt.savefig('../../reports/figures/visual21.png')

# %% [markdown]
# **There appears to be no significant changes in the assumptions.**

# %% [markdown]
# ## Model 4: bldggrade
# After an in depth look at the features of bathroom counts and the square footage of various featuresI'll now proceed with adding the highest correlated value with sale price: bldggrade (building grade).

# %%
kc_data['bldggrade'].unique()
# Out:
# array([ 7,  8,  9, 10,  6,  5, 11, 12,  4,  3,  1], dtype=int64)

# %% [markdown]
# According to our lookup file, the codes translate to as follows:
#
# **1**  Cabin **2**  Substandard **3**  Poor **4**  Low **5**  Fair **6**  Low Average **7**  Average **8**  Good **9**  Better **10** Very Good **11** Excellent **12** Luxury
#
# Once I generate plots, I will dummy out these categories so I can add them to our model.

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.barplot(x="bldggrade", y="saleprice", data=kc_data, palette='Spectral')
ax.set_title('Average Sale Price per Building Grade', fontsize = 12)
ax.tick_params(axis='both', labelsize=10)
plt.xlabel('Building Grade', fontsize = 10)
plt.ylabel('Sale Price', fontsize = 10)
plt.savefig('../../reports/figures/visual22.png')
plt.tight_layout()

# %% [markdown]
# This visualization is understandable, as naturally houses with a poor build grade will sell for less than those that are well built. Interestingly so, cabins (represented as '1') on average have the highest sale prices, most likely due to their location and exclusitivity (secluded mountains, lakeside, etc.) For the sake of this analysis, I will possibly consider dropping the 'cabin' value and examining the performance of the model after.

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = 'bldggrade', y = 'saleprice', data = kc_data, scatter_kws={"color": "#298A08"},
            line_kws={"color": "#DF7401"});
ax.set_title(' Linear Relationship Between Sale Price and Building Grade', fontsize = 12)
ax.tick_params(axis='both', labelsize=10)
plt.xlabel('Building Grade', fontsize = 10)
plt.ylabel('Sale Price', fontsize = 10)
plt.savefig('../../reports/figures/visual23.png')
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.title('Building Grade', fontsize = 20)
sns.distplot(kc_data.bldggrade, ax = ax)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Building Grade', fontsize = 10)
plt.savefig('../../reports/figures/visual24.png')
plt.tight_layout()
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Since the distribution looks fairly balanced, I will use it in my model.
# I'll now create the dummy values in preparation for my model.

# %%
bldggrade_dummies = pd.get_dummies(kc_data['bldggrade'], prefix='bldggr', drop_first=True)

kc_data = pd.concat([kc_data, bldggrade_dummies], axis=1)

# %%
#Adding bldg grades to our features
bldg_cols = []
for column in kc_data.columns:
    if column.startswith('bldggr'):
        bldg_cols.append(column)
        
model_features4 = model_features3 + bldg_cols

# %%
model4 = model(model_features4, kc_data, 'saleprice')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.425
# Model:                            OLS   Adj. R-squared:                  0.425
# Method:                 Least Squares   F-statistic:                     1728.
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):               0.00
# Time:                        12:03:05   Log-Likelihood:            -4.5636e+05
# No. Observations:               32722   AIC:                         9.128e+05
# Df Residuals:                   32707   BIC:                         9.129e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.845e+06   3.11e+05      5.937      0.000    1.24e+06    2.45e+06
# sqrt_sqfttotliving  1.192e+04    308.169     38.692      0.000    1.13e+04    1.25e+04
# bathtotcount       -9110.8784   3327.922     -2.738      0.006   -1.56e+04   -2588.030
# sqrt_enclosedporch  4662.6610    638.695      7.300      0.000    3410.796    5914.526
# sqrt_deck_sqft      2121.2381    179.092     11.844      0.000    1770.210    2472.266
# bldggrade          -1.515e+05   3.49e+04     -4.342      0.000    -2.2e+05   -8.31e+04
# bldggr_3           -1.306e+06    2.4e+05     -5.442      0.000   -1.78e+06   -8.35e+05
# bldggr_4           -1.198e+06   1.78e+05     -6.718      0.000   -1.55e+06   -8.48e+05
# bldggr_5           -1.048e+06   1.37e+05     -7.631      0.000   -1.32e+06   -7.79e+05
# bldggr_6           -8.882e+05   1.02e+05     -8.695      0.000   -1.09e+06   -6.88e+05
# bldggr_7           -6.827e+05   6.76e+04    -10.104      0.000   -8.15e+05    -5.5e+05
# bldggr_8           -4.123e+05   3.38e+04    -12.183      0.000   -4.79e+05   -3.46e+05
# bldggr_9           -4.349e+04   1.28e+04     -3.392      0.001   -6.86e+04   -1.84e+04
# bldggr_10           3.193e+05   4.04e+04      7.906      0.000     2.4e+05    3.98e+05
# bldggr_11           6.568e+05   7.51e+04      8.745      0.000     5.1e+05    8.04e+05
# bldggr_12           9.753e+05   1.17e+05      8.346      0.000    7.46e+05     1.2e+06
# ==============================================================================
# Omnibus:                     7140.300   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22465.769
# Skew:                           1.116   Prob(JB):                         0.00
# Kurtosis:                       6.390   Cond. No.                     3.20e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.71e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Our $R^2$ value increased dramatically from 0.324 to 0.425! And we still have low p-values for each coefficient (all below $\alpha$ = 0.05). A quick look at the assumptions:

# %%
normality_assumption(model4)
plt.savefig('../../reports/figures/visual25.png')

# %%
homoscedasticity(model4, kc_data)
plt.savefig('../../reports/figures/visual26.png')

# %% [markdown]
# There are very noticable differences between this and our third model. The bottom tail of our residuals is hugging a bit closer to the line and a number of valuse are below the line - previously all of the lower end values were drifting up and away. Higher values are still off, which is to be expected due to our right skewed target variable.
#
# There are some changes in our scatter plot of the residuals with it being a lot less cone shaped and more sporatic towards higher values. There still is a cluster at lower - mid range values but overall the homoscedasticity has imporved.
#
# As of now, with the improved assumptions and $R^2$  value, this is the best model yet!

# %% [markdown]
# ## Model 5: Township (Location!)
# As seen in the correlation matrix above, township had a correlation value of 0.469307 with saleprice. I've chosen to add it to my model because location is one of the most important factors in real estate.

# %%
kc_data['township'] = kc_data['township'].astype('int')

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = 'township', y = 'saleprice', data = kc_data, scatter_kws={"color": "#298A08"},
            line_kws={"color": "#DF7401"});
ax.set_title('Township Vs. Sale Price Scatter plot', fontsize = 12)
ax.tick_params(axis='both', labelsize=10)
plt.xlabel('Township', fontsize = 10)
plt.ylabel('Sale Price', fontsize = 10)
plt.savefig('../../reports/figures/visual27.png')
plt.tight_layout()

# %% [markdown]
# ## Average Sale Price per Township

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.barplot(x="township", y="saleprice", data=kc_data)
ax.set_title('Average Sale Price per Township', fontsize = 12)
ax.tick_params(axis='both', labelsize=10)
plt.xlabel('Township', fontsize = 10)
plt.ylabel('Sale Price', fontsize = 10)
plt.savefig('../../reports/figures/visual28.png')
plt.tight_layout()

# %%
township_dummies = pd.get_dummies(kc_data['township'], prefix='twnshp', drop_first=True)

kc_data = pd.concat([kc_data, township_dummies], axis=1) #<-Updating data frame

# %%
town_cols = []
for column in kc_data.columns:
    if column.startswith('twnshp'):
        town_cols.append(column)

# %%
model_features5 = model_features4 + town_cols

# %%
model5 = model(model_features5, kc_data, 'saleprice')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.685
# Model:                            OLS   Adj. R-squared:                  0.685
# Method:                 Least Squares   F-statistic:                     3384.
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):               0.00
# Time:                        12:03:10   Log-Likelihood:            -4.4653e+05
# No. Observations:               32722   AIC:                         8.931e+05
# Df Residuals:                   32700   BIC:                         8.933e+05
# Df Model:                          21
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            1.22e+06   2.48e+05      4.929      0.000    7.35e+05    1.71e+06
# sqrt_sqfttotliving  1.403e+04    228.803     61.327      0.000    1.36e+04    1.45e+04
# bathtotcount        6653.5798   2469.498      2.694      0.007    1813.273    1.15e+04
# sqrt_enclosedporch  1554.3921    473.666      3.282      0.001     625.989    2482.795
# sqrt_deck_sqft      1675.1486    132.832     12.611      0.000    1414.794    1935.504
# bldggrade          -1.329e+05   2.58e+04     -5.146      0.000   -1.84e+05   -8.23e+04
# bldggr_3           -1.005e+06   1.78e+05     -5.656      0.000   -1.35e+06   -6.57e+05
# bldggr_4           -8.831e+05   1.32e+05     -6.688      0.000   -1.14e+06   -6.24e+05
# bldggr_5           -7.729e+05   1.02e+05     -7.598      0.000   -9.72e+05   -5.73e+05
# bldggr_6           -6.896e+05   7.57e+04     -9.115      0.000   -8.38e+05   -5.41e+05
# bldggr_7           -5.538e+05      5e+04    -11.065      0.000   -6.52e+05   -4.56e+05
# bldggr_8           -3.588e+05   2.51e+04    -14.296      0.000   -4.08e+05    -3.1e+05
# bldggr_9           -7.712e+04   9611.702     -8.023      0.000    -9.6e+04   -5.83e+04
# bldggr_10           2.242e+05      3e+04      7.482      0.000    1.65e+05    2.83e+05
# bldggr_11           5.389e+05   5.57e+04      9.683      0.000     4.3e+05    6.48e+05
# bldggr_12           8.082e+05   8.66e+04      9.336      0.000    6.39e+05    9.78e+05
# twnshp_20           5.581e+04   9.19e+04      0.607      0.544   -1.24e+05    2.36e+05
# twnshp_21           9606.4377   9.15e+04      0.105      0.916    -1.7e+05    1.89e+05
# twnshp_22           5.562e+04   9.15e+04      0.608      0.543   -1.24e+05    2.35e+05
# twnshp_23           1.351e+05   9.14e+04      1.478      0.139   -4.41e+04    3.14e+05
# twnshp_24           3.758e+05   9.14e+04      4.110      0.000    1.97e+05    5.55e+05
# twnshp_25           5.586e+05   9.14e+04      6.109      0.000    3.79e+05    7.38e+05
# twnshp_26           3.111e+05   9.14e+04      3.403      0.001    1.32e+05     4.9e+05
# ==============================================================================
# Omnibus:                    11171.721   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            96004.489
# Skew:                           1.400   Prob(JB):                         0.00
# Kurtosis:                      10.910   Cond. No.                     3.17e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.85e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# This is the most significant increase of our $R^2$ value from 0.425 to 0.685! This time, however, there are very high p-values for townships 20, 21, 22 and 23. Interestingly though, these townships were showing similar average sale prices in the bar graph above. This now makes sense since, as we saw in the bar graph that the sale price is dominated by townships 24-26. Thus, these higher p-values for these coefficients suggest that there isn't significant evidence that these townships affect sale price.
#
# As for the normality and homoscedasticity:

# %%
normality_assumption(model5)
plt.savefig('../../reports/figures/visual29.png')

# %%
homoscedasticity(model5, kc_data)
plt.savefig('../../reports/figures/visual30.png')

# %% [markdown]
# **Normality assumption** has improved a bit on the lower tail, with fewer trailing residuals at the bottom, the middle hugging the line quite tightly and the top end seemingly worse have gotten worse, leading away from the line more steeply than in model 4 - although this is harder to tell since our scales has changed here. **I can conclude that model 5 mildly meets the normality assumption.**
#
# **Homoscedasticity** appears to have also gotten slightly worse. The increase in scale could have something to do with to the fact that I have added more features. There still is a slight cone like shape to the left end, somewhat similar to model 4 on a different scale but noticibly different. Model 5 moderately meets the homoscedasticity assumption.

# %% [markdown]
# The $R^2$  has overall increased from 0.320 to 0.685 and steadily improved on the assumptions have been made. And with this, I am content with the model I've built! However, in examining the results, a potential issue I've noticed is that a few features have a negative coefficient when there is a positive correlation. To make our model interpretable, I will remove them

# %%
#Drop bldggrade, z_bldggrade, bldggr_8, z_bldggr_8, and bldgrr_9
kc_data = kc_data.drop(columns=['bldggrade', 'bldggr_8', 'bldggr_9', 'sqrt_sqfttotliving'])

# %% [markdown]
# ## Validating the Model

# %% [markdown]
# The final piece in evaluating the quality of the model is cross-validation to provide an idea of how the model would perform with new data for the same variables. Using sklearn's train_test_split function I'll split the data into two subsets: one that the model will be trained on, and another that it will be tested on. By default, the function takes 75% of the data as the training subset and the other 25% as its test subset.
#
# I'll create train and test data for the x and y variables, use the x subsets to predict new y values, then calculate the distance between these and the actual y-values. Lastly, I'll use the mean_squared_error function to calculate the MSE for both subsets.

# %%
X_train, X_test, y_train, y_test = train_test_split(kc_data, kc_data.saleprice)
train, test = train_test_split(kc_data,test_size=.25,shuffle=True)

# %%
f_train = pd.DataFrame(X_train, y_train)
df_test = pd.DataFrame(X_test, y_test)

# %%
#Examining the shape of the subsets
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (24541, 39) (24541,) (8181, 39) (8181,)

# %%
#Fitting the data 
linreg = LinearRegression()
model = linreg.fit(X_train, y_train)
#Checking accuracy
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
train_preds = model.predict(X_train)
test_preds = model.predict(X_test)

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %%
train_mse = np.mean(y_train-y_pred_train)**2
test_mse = np.mean(y_test-y_pred_test)**2

train_r2 = r2_score(train['saleprice'], model.predict(train))
test_r2 = r2_score(test['saleprice'], model.predict(test))

print('Mean Squared Error Train:', train_mse)
print('Mean Squared Error Test:', test_mse)
print(f'R-Squared Train = {round(train_r2,2)}')
print(f'R-Squared Test = {round(test_r2,2)}')
# Out:
# Mean Squared Error Train: 2.558094549581002e-21
# Mean Squared Error Test: 2.5980273310662097e-21
# R-Squared Train = 1.0
# R-Squared Test = 1.0

# %% [markdown]
# The MSE and $R^2$ values for the train and test subsets are similar. This suggests that the model will perform similarly on different data.

# %%
X_train = sm.add_constant(X_train)
smmodel = sm.OLS(y_train, X_train).fit()
smmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.320e+31
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):               0.00
# Time:                        12:03:11   Log-Likelihood:             4.6188e+05
# No. Observations:               24541   AIC:                        -9.237e+05
# Df Residuals:                   24503   BIC:                        -9.234e+05
# Df Model:                          37
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               3.783e-10   1.03e-09      0.368      0.713   -1.64e-09    2.39e-09
# saleprice              1.0000   5.23e-17   1.91e+16      0.000       1.000       1.000
# sqfttotliving      -2.931e-14   3.06e-14     -0.959      0.338   -8.92e-14    3.06e-14
# yrbuilt            -3.411e-13   5.73e-13     -0.595      0.552   -1.46e-12    7.83e-13
# yrrenovated         1.066e-14   2.52e-14      0.423      0.672   -3.87e-14       6e-14
# bedrooms            7.731e-12   1.55e-11      0.498      0.619   -2.27e-11    3.82e-11
# zipcode            -1.943e-15   1.81e-15     -1.071      0.284    -5.5e-15    1.61e-15
# sqfttotbasement    -2.753e-14   4.02e-14     -0.685      0.494   -1.06e-13    5.13e-14
# sqftfinbasement     3.997e-14   6.02e-14      0.664      0.507    -7.8e-14    1.58e-13
# sqftopenporch      -1.297e-13   8.81e-14     -1.472      0.141   -3.02e-13     4.3e-14
# sqftenclosedporch   4.547e-13   5.15e-13      0.883      0.377   -5.55e-13    1.46e-12
# sqftdeck            1.137e-13   1.44e-13      0.790      0.429   -1.68e-13    3.96e-13
# heatsystem          1.364e-11   1.12e-11      1.218      0.223   -8.32e-12    3.56e-11
# bathhalfcount       1.319e-11   2.15e-11      0.613      0.540   -2.89e-11    5.53e-11
# bath3qtrcount        9.55e-12   1.51e-11      0.632      0.528   -2.01e-11    3.92e-11
# bathfullcount      -2.274e-11   1.37e-11     -1.663      0.096   -4.95e-11    4.07e-12
# condition           8.413e-12    1.6e-11      0.526      0.599   -2.29e-11    3.98e-11
# sqftgarageattached  3.197e-14   5.39e-14      0.593      0.553   -7.37e-14    1.38e-13
# finbasementgrade    2.274e-13   6.74e-12      0.034      0.973    -1.3e-11    1.34e-11
# inadequateparking  -6.139e-12    1.1e-11     -0.557      0.578   -2.77e-11    1.55e-11
# township            7.503e-11   4.54e-11      1.651      0.099    -1.4e-11    1.64e-10
# trafficnoise        6.366e-12    1.9e-11      0.335      0.738   -3.09e-11    4.36e-11
# bathtotcount       -1.319e-11   1.64e-11     -0.806      0.420   -4.53e-11    1.89e-11
# sqrt_enclosedporch -1.728e-11   9.11e-12     -1.896      0.058   -3.51e-11    5.84e-13
# sqrt_deck_sqft      2.274e-13   3.41e-12      0.067      0.947   -6.46e-12    6.92e-12
# bldggr_3             4.22e-10    9.4e-10      0.449      0.654   -1.42e-09    2.26e-09
# bldggr_4           -8.731e-11   3.43e-10     -0.255      0.799    -7.6e-10    5.85e-10
# bldggr_5           -4.184e-11   9.91e-11     -0.422      0.673   -2.36e-10    1.52e-10
# bldggr_6           -3.411e-11   4.87e-11     -0.701      0.483   -1.29e-10    6.13e-11
# bldggr_7            4.547e-12   2.94e-11      0.155      0.877   -5.31e-11    6.22e-11
# bldggr_10           7.276e-11   6.33e-11      1.149      0.251   -5.14e-11    1.97e-10
# bldggr_11          -7.276e-11   1.26e-10     -0.579      0.563   -3.19e-10    1.74e-10
# bldggr_12           2.619e-10   4.09e-10      0.640      0.522   -5.41e-10    1.06e-09
# twnshp_20           2.183e-10    7.2e-10      0.303      0.762   -1.19e-09    1.63e-09
# twnshp_21          -3.347e-10   7.07e-10     -0.474      0.636   -1.72e-09    1.05e-09
# twnshp_22           2.474e-10   7.01e-10      0.353      0.724   -1.13e-09    1.62e-09
# twnshp_23           7.276e-11   6.98e-10      0.104      0.917   -1.29e-09    1.44e-09
# twnshp_24           4.366e-11   6.99e-10      0.062      0.950   -1.33e-09    1.41e-09
# twnshp_25           1.455e-10   7.04e-10      0.207      0.836   -1.23e-09    1.52e-09
# twnshp_26          -2.547e-10   7.07e-10     -0.360      0.719   -1.64e-09    1.13e-09
# ==============================================================================
# Omnibus:                      962.705   Durbin-Watson:                   0.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2708.025
# Skew:                           0.145   Prob(JB):                         0.00
# Kurtosis:                       4.601   Cond. No.                     1.12e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.25e-16. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#Determining final p-value
from statsmodels.stats.diagnostic import het_goldfeldquandt

name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(smmodel.resid, smmodel.model.exog)
list(zip(name, test))
# Out:
# [('F statistic', 0.9946091686319449), ('p-value', 0.6174973868025084)]

# %% [markdown]
# ## A Quick Claim Validation: Does having a deck increases home sale price?

# %%
kc_data['has_deck'] = np.where(kc_data['sqftdeck'] > 0, 'yes', 'no')

# %%
kc_data.groupby(['has_deck'])['saleprice'].mean()
# Out:
# has_deck
# no     658367.997328
# yes    765387.151093
# Name: saleprice, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.barplot(x = "has_deck", y = "saleprice", data = kc_data)
ax.set_title('Average Sale Price for Deck vs. No Deck', fontsize = 12)
ax.tick_params(axis = 'both', labelsize = 10)
plt.xlabel('Porch Status', fontsize = 10)
plt.ylabel('Sale Price', fontsize = 10)
plt.savefig('../../reports/figures/visual31.png')
plt.tight_layout()

# %% [markdown]
# So, we can see here that houses with decks do tend to have a higher average sale price. The average sale price for a house with a deck is $\$765,387$ and with out a deck is $\$658,367$.

# %% [markdown]
# # Summary
# After a thorough analysis, I've came to the conclusion as follows:
#
# **1- Total living square footage is a major factor in the price of a home.** The larger the home, the pricier. On this note, should a homeowner wish to increase the price of their home before selling by adding to it's living space, **converting the garage to an additional bedroom is a highly profitable choice.**
#
# **2- The grade of a house has the *greatest* effect on it's value.** A surefire way to instantly add value to a home is to upgrade the construction using the highest quality materials.
#
# **3 - Location, location, and again, location.** The location of a home, be it determined by zip code or township, is a great predictor of the price of a home. If a well built, high quality home is contructed in a bad area, most likely the home owner will have a difficult time sell *or* will have to comprimise on it's sale price. On the flip side, a run down home in a highly sought after area usually doesn't lose too much value since many people are willing to make the purchase with the intent of fixing it up.
#
# **4 - Enclosed porches and decks add to the value of a home.** Home owners appreciate having the ability to enjoy the outdoors while maintaining a slight sense of seclusion.
#
# **5- The number of bathrooms factors into the high sale price of the house.** The more bathrooms, the more valuable.
#
# I'd recommend new home buyers to consider the **location** of the home first, then **size (square footage)**, and then **grade** to maximize the potential of their new home experience.
#
# My recommendations for diy and fix-it-up home owners who are looking to get the most value out of one of the largest investments they've made, is to **add an extra bedroom, an additional bathroom and outdoor living space.**
#
#
# **The model does have some limitations**: given that some of the variables needed to be log and sqrt-transformed to satisfy regression assumptions, any new data used with this model would need to undergo similar processing. In addition, considering regional differences in housing prices, this model's applicability to data from other counties may be limited. And lastly, since outliers were removed, the model may not accurately predict extreme values.
