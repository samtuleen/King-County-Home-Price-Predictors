# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sale_info = pd.read_csv('../../data/raw/EXTR_RPSale.csv')
sale_info.head(2)
# Out:
#    ExciseTaxNbr   Major  Minor DocumentDate  SalePrice    RecordingNbr Volume  \
# 0       2857854  198920   1430   03/28/2017          0  20170410000541
# 1       2743355  638580    110   07/14/2015     190000  20150715002686
#
#   Page PlatNbr PlatType  ... PropertyType PrincipalUse SaleInstrument  \
# 0                        ...            3            7             15
# 1                        ...            3            6              3
#
#   AFForestLand  AFCurrentUseLand  AFNonProfitUse  AFHistoricProperty  \
# 0            N                 N               N                   N
# 1            N                 N               N                   N
#
#   SaleReason PropertyClass SaleWarning
# 0         16             2       20 31
# 1          1             8          15
#
# [2 rows x 24 columns]

# %%
to_drop = ['Volume','Page','PlatNbr', 'PlatType', 'PlatLot', 'PlatBlock', 'AFForestLand','AFCurrentUseLand',
          'AFNonProfitUse', 'AFHistoricProperty', 'SellerName', 'BuyerName', 'SaleReason', 'PropertyClass', 'SaleWarning']
sale_info.drop(to_drop, axis=1, inplace=True)

# %%
sale_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351067 entries, 0 to 351066
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ExciseTaxNbr    351067 non-null  int64
#  1   Major           351067 non-null  int64
#  2   Minor           351067 non-null  int64
#  3   DocumentDate    351067 non-null  object
#  4   SalePrice       351067 non-null  int64
#  5   RecordingNbr    351067 non-null  object
#  6   PropertyType    351067 non-null  int64
#  7   PrincipalUse    351067 non-null  int64
#  8   SaleInstrument  351067 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 24.1+ MB

# %%
housing_data = pd.read_csv('../../data/raw/EXTR_ResBldg.csv')
housing_data.head(2)
# Out:
#    Major  Minor  BldgNbr  NbrLivingUnits                     Address  \
# 0   9800    720        1               1  27719  SE 26TH WAY   98075
# 1   9802    140        1               1  2829   277TH TER SE  98075
#
#   BuildingNumber Fraction DirectionPrefix                 StreetName  \
# 0          27719                       SE  26TH
# 1          2829                            277TH
#
#   StreetType  ... FpMultiStory FpFreestanding  FpAdditional  YrBuilt  \
# 0     WAY     ...            0              0             0     2001
# 1     TER     ...            0              0             0     2004
#
#    YrRenovated  PcntComplete  Obsolescence  PcntNetCondition  Condition  \
# 0            0             0             0                 0          3
# 1            0             0             0                 0          3
#
#    AddnlCost
# 0          0
# 1          0
#
# [2 rows x 50 columns]

# %%
to_drop2 = ['DirectionPrefix', 'DirectionSuffix', 'ZipCode', 'Fraction', 'FpFreestanding', 'FpAdditional',
                  'YrRenovated', 'PcntComplete', 'PcntNetCondition', 'AddnlCost','FpMultiStory', 'Obsolescence',
                  'ViewUtilization', 'BrickStone', 'FpSingleStory','BrickStone', 'FpSingleStory', 'FinBasementGrade',
                   'StreetName', 'StreetType', 'BldgGradeVar', 'SqFtHalfFloor', 'SqFtUnfinFull', 'SqFtUnfinHalf']
housing_data.drop(to_drop2, axis= 1, inplace=True)

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181510 entries, 0 to 181509
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Major               181510 non-null  int64
#  1   Minor               181510 non-null  int64
#  2   BldgNbr             181510 non-null  int64
#  3   NbrLivingUnits      181510 non-null  int64
#  4   Address             181510 non-null  object
#  5   BuildingNumber      181510 non-null  object
#  6   Stories             181510 non-null  float64
#  7   BldgGrade           181510 non-null  int64
#  8   SqFt1stFloor        181510 non-null  int64
#  9   SqFt2ndFloor        181510 non-null  int64
#  10  SqFtUpperFloor      181510 non-null  int64
#  11  SqFtTotLiving       181510 non-null  int64
#  12  SqFtTotBasement     181510 non-null  int64
#  13  SqFtFinBasement     181510 non-null  int64
#  14  SqFtGarageBasement  181510 non-null  int64
#  15  SqFtGarageAttached  181510 non-null  int64
#  16  DaylightBasement    181510 non-null  object
#  17  SqFtOpenPorch       181510 non-null  int64
#  18  SqFtEnclosedPorch   181510 non-null  int64
#  19  SqFtDeck            181510 non-null  int64
#  20  HeatSystem          181510 non-null  int64
#  21  HeatSource          181510 non-null  int64
#  22  Bedrooms            181510 non-null  int64
#  23  BathHalfCount       181510 non-null  int64
#  24  Bath3qtrCount       181510 non-null  int64
#  25  BathFullCount       181510 non-null  int64
#  26  YrBuilt             181510 non-null  int64
#  27  Condition           181510 non-null  int64
# dtypes: float64(1), int64(24), object(3)
# memory usage: 38.8+ MB

# %%
parcel = pd.read_csv('../../data/raw/EXTR_Parcel.csv')
parcel.head(2)
# Out:
#    Unnamed: 0   Major  Minor PropName                            PlatName  \
# 0           0  807841    410                      SUMMER RIDGE DIV NO. 02
# 1           2  755080     15           SANDER'S TO GILMAN PK & SALMON BAY
#
#           PlatLot PlatBlock  Range  Township  Section  ... SeismicHazard  \
# 0  41                            6        25       22  ...             N
# 1  3                1            3        25       11  ...             N
#
#   LandslideHazard  SteepSlopeHazard  Stream  Wetland  SpeciesOfConcern  \
# 0               N                 N       N        N                 N
# 1               N                 N       N        N                 N
#
#   SensitiveAreaTract  WaterProblems TranspConcurrency  OtherProblems
# 0                  N              N                 N              N
# 1                  N              N                 N              N
#
# [2 rows x 82 columns]

# %%
parcel = parcel[['Major', 'Minor', 'SqFtLot', 'TrafficNoise','OtherNuisances']]
parcel.head()
# Out:
#     Major  Minor  SqFtLot  TrafficNoise OtherNuisances
# 0  807841    410     7424             0              N
# 1  755080     15     5000             0              N
# 2  888600    135   277041             0              N
# 3   22603   9181    10560             0              N
# 4  229670    160     9853             0              N

# %%
display(parcel['TrafficNoise'].value_counts())
display("Traffic noise ranges on a scale of 0 to 3, 0 is no noise, 1 being moderate, 2 being high, and 3 being extreme")
# Out:
# 0    176076
# 1     16736
# 2     10563
# 3      1824
# Name: TrafficNoise, dtype: int64
# 'Traffic noise ranges on a scale of 0 to 3, 0 is no noise, 1 being moderate, 2 being high, and 3 being extreme'

# %%
parcel['OtherNuisances'].value_counts()
# Out:
# N    199057
# Y      6142
# Name: OtherNuisances, dtype: int64
